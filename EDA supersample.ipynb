# %% [markdown]
# ### GRIP: The Spark Foundation
# ### Data Science And Business Analytics Intern
# ### Exploratory Data Analysis SampleSuperstore
# ## Name: Ashish

# %% [markdown]
# ### Importing all the necessary libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Reading the csv file

# %%
df = pd.read_csv('SampleSuperstore.csv')

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# There is no null value in the dataset

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.shape
# Out:
# (9994, 13)

# %%
df.duplicated().sum()
# Out:
# 17

# %%
df.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
df['Postal Code'] = df['Postal Code'].astype('object')

# %% [markdown]
# #### Removing the duplicate rows from the data

# %%
df.drop_duplicates(subset = None,keep = 'first',inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
corr = df.corr()
sns.heatmap(corr,annot = True)
# Out:
# <AxesSubplot:>

# %%
df = df.drop(['Postal Code'],axis = 1)

# %%
sns.pairplot(df,hue = 'Ship Mode')

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5955
# Second Class      1943
# First Class       1537
# Same Day           542
# Name: Ship Mode, dtype: int64

# %% [markdown]
# #### ploting No. of sales accodign to the Ship Mode

# %%
plt.figure(figsize = (6,4))
sns.countplot(x = 'Ship Mode',data = df)
plt.show()

# %% [markdown]
# here we can clearly see that standard class has higheer no of sales.

# %%
plt.figure(figsize = (6,4))
sns.barplot(x = 'Ship Mode', y = 'Profit',data =df)
plt.show()

# %% [markdown]
# here First Class has highest mean profit

# %% [markdown]
# ### Segment wise analysis

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5183
# Corporate      3015
# Home Office    1779
# Name: Segment, dtype: int64

# %%
plt.figure(figsize = (5,5))
sns.countplot(x = 'Segment',data = df)
plt.show()

# %% [markdown]
# Here consumers has the highest no. of sales

# %%
plt.figure(figsize = (5,5))
sns.barplot(x = 'Segment',y = 'Profit',data = df)
plt.show()

# %% [markdown]
# but Home Office has the highest mean profit

# %% [markdown]
# ### Category wise analysis

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    6012
# Furniture          2118
# Technology         1847
# Name: Category, dtype: int64

# %%
plt.figure(figsize = (5,5))
sns.countplot(x = 'Category',data = df)
plt.show()

# %% [markdown]
# office supplies has highest no of sales

# %%
plt.figure(figsize = (5,5))
sns.barplot(x = 'Category',y = 'Profit',data = df)
plt.show()

# %% [markdown]
# Technology has highest mean value of profit

# %% [markdown]
# ### Office Supplies wise Analysis

# %%
office = df[df['Category'] == 'Office Supplies']

# %%
plt.figure(figsize = (8,5))
sns.countplot(x = 'Sub-Category',data = office)
plt.show()

# %% [markdown]
# Blinders and Paper has highest no of sales

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'Sub-Category',y = 'Profit',data = office)
plt.show()

# %% [markdown]
# Appliances has the highest mean profit but supplies has negative mean profit we need to look at this and try to improve profit

# %% [markdown]
# ### Technology wise Analysis

# %%
tech = df[df['Category'] == 'Technology']

# %%
plt.figure(figsize = (8,5))
sns.countplot(x = 'Sub-Category',data = tech)
plt.show()

# %% [markdown]
# Phones and Accessories has the highest no of Sales

# %%
plt.figure(figsize = (8,5))
sns.barplot(x = 'Sub-Category',y = 'Profit',data = tech)
plt.show()

# %% [markdown]
# Copiers has very less sale but has highest profit we can improve others profit

# %% [markdown]
# ### Furniture wise Analysis

# %%
furn = df[df['Category'] == 'Furniture']

# %%
plt.figure(figsize = (8,5))
sns.countplot(x = 'Sub-Category',data = furn)
plt.show()

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'Sub-Category',y = 'Profit',data = furn)
plt.show()

# %% [markdown]
# Bookcases and Tables has high negative mean profit we need to improve the profit of these two

# %%
df['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %% [markdown]
# ### Region Wise Analysis

# %%
sns.set_style("whitegrid")
sns.barplot(x = df["Region"], y = df['Sales'])
# sns.barplot(x = df["Region"], y = df['Sales'],hue = df["Category"] ,ax = axes[0])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %% [markdown]
# South Region has highest mean Sales

# %%
plt.figure(figsize = (8,5))
sns.set_style("whitegrid")
# sns.barplot(x = df["Region"], y = df['Sales'])
sns.barplot(x = df["Region"], y = df['Sales'],hue = df["Category"])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Sales'>

# %%
plt.figure(figsize = (8,5))
sns.set_style("whitegrid")
# sns.barplot(x = df["Region"], y = df['Sales'])
sns.barplot(x = df["Region"], y = df['Profit'],hue = df["Category"])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Profit'>

# %% [markdown]
# Furniture has negative mean profit in Central region we need to improve our profit in that region

# %%
central = df[df["Region"] == 'Central']

# %%
sns.distplot(central['Sales'])
# Out:
# C:\Users\Ashish\miniconda3\envs\NB_2657\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'State',y = 'Sales',data = central)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'State',y = 'Profit',data = central)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
South = df[df["Region"] == 'South']

# %%
sns.distplot(South['Sales'])
# Out:
# C:\Users\Ashish\miniconda3\envs\NB_2657\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'State',y = 'Sales',data = South)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize = (15,5))
sns.barplot(x = 'State',y = 'Profit',data = South)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %% [markdown]
# Florida and Tennesse has negative profit we need to lookout and improve our profit

# %%
East = df[df["Region"] == 'East']

# %%
sns.distplot(East['Sales'])
# Out:
# C:\Users\Ashish\miniconda3\envs\NB_2657\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Sales', ylabel='Density'>

# %%
plt.figure(figsize = (18,6))
sns.barplot(x = 'State',y = 'Sales',data = East)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize = (18,5))
sns.barplot(x = 'State',y = 'Profit',data = East)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>

# %%
West = df[df["Region"] == 'West']

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'State',y = 'Sales',data = West)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Sales'>

# %%
plt.figure(figsize = (10,5))
sns.barplot(x = 'State',y = 'Profit',data = West)
# Out:
# <AxesSubplot:xlabel='State', ylabel='Profit'>
